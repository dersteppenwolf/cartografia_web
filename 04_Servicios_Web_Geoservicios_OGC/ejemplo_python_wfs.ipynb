# %% [markdown]
# # Ejemplo python

# %%
print("hola mundo fsdafsa")
# Out:
# hola mundo fsdafsa

# %%
a = 1

# %%
b = 2

# %%
print (1 + 2)
# Out:
# 3

# %%
def sumar (a, b):
    return a + b

# %%
sumar(44,6)
# Out:
# 50

# %% [markdown]
# # Consumir servicio WFS directamente a través de HTTP

# %%
import requests
url_capabilities = "https://gw-geoportal-test.igac.gov.co/geoservices/catastro/wfs?version=2.0.0&request=GetCapabilities"
r = requests.get(url_capabilities, verify=False)
print( r.text  )
# Out:
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:851: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...

# %%
import xml.dom.minidom

dom = xml.dom.minidom.parseString( r.text)
pretty_xml_as_string = dom.toprettyxml()
print(pretty_xml_as_string)
# Out:
# <?xml version="1.0" ?>
# <wfs:WFS_Capabilities updateSequence="2373" version="2.0.0" xmlns="http://www.opengis.net/wfs/2.0" xmlns:catastro="http://catastro" xmlns:fes="http://www.opengis.net/fes/2.0" xmlns:gml="http://www.opengis.net/gml/3.2" xmlns:ows="http://www.opengis.net/ows/1.1" xmlns:wfs="http://www.opengis.net/wfs/2.0" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xml="http://www.w3.org/XML/1998/namespace" xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.opengis.net/wfs/2.0 http://gw-geoportal-test.igac.gov.co/geoservices/schemas/wfs/2.0/wfs.xsd">
# 	<ows:ServiceIdentification>
# 		<ows:Title>GeoServer Web Feature Service</ows:Title>
# 		<ows:Abstract>This is the reference implementation of WFS 1.0.0 and WFS 1.1.0, supports all WFS operations including Transaction.</ows:Abstract>
# 		<ows:Keywords>
# 			<ows:Keyword>WFS</ows:Keyword>
# 			<ows:Keyword>WMS</ows:Keyword>
# ...

# %% [markdown]
# # Consumir servicio wfs utilizando owslib

# %%
# !pip3 install owslib

# %%
from owslib.wfs import WebFeatureService

# %%
wfs_url = "http://serviciosgis.ideca.gov.co/geoserver/wfs"
    
wfs_client = WebFeatureService(url=wfs_url, version='2.0.0')
contents = list(wfs_client.contents)
for layer in contents:
    #logging.info(wfs_client[layer])
    name = layer.split(":")
    title = wfs_client[layer].title
    abstract = wfs_client[layer].abstract
    print (name , title, " : ", abstract)
# Out:
# ['mapareferencia', 'ANDE'] Andén  :  Zona o franja paralela a la vía de uso vehicular, destinada a la permanencia o tránsito de peatones. Su superficie debe ser dura para su circulación no obstante, dependiendo de la tipología que se defina, pueden generarse composiciones con superficies blandas (zonas verdes). Generalmente el andén se encuentra a un nivel superior al de la calzada para proteger al peatón del tráfico de la escorrentía superficial. El andén puede estar constituido por franjas que delimitan usos específicos.
# ['mbase', 'ANDE'] Andén  :  None
# ['mbase', 'ARBOURB'] Arbolado  :  None
# ['mbase', 'ARBOURB_10K'] Arbolado 10K  :  None
# ['mbase', 'ARBOURB_20K'] Arbolado 20K  :  None
# ['mbase', 'ARBOURB_50K'] Arbolado 50K  :  None
# ['mbase', 'ARBOURB_5K'] Arbolado 5K  :  None
# ['lectura', 'BIBLIOPUBLICA'] Bibliotecas Públicas de Bogotá - BibloRed  :  None
# ['lectura', 'BIBLIOESTACION'] Bibloestaciones de Transmilenio  :  None
# ...
